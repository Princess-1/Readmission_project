# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
# %matplotlib notebook

# %%
# !pwd
# Out:
# /Users/Princess/Personal_projects/Readmission_proj

# %%
df = pd.read_csv('diabetic_readmission_data.csv')
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital    ...     citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
# encounter_id                101766 non-null int64
# patient_nbr                 101766 non-null int64
# race                        101766 non-null object
# gender                      101766 non-null object
# age                         101766 non-null object
# weight                      101766 non-null object
# admission_type_id           101766 non-null int64
# discharge_disposition_id    101766 non-null int64
# admission_source_id         101766 non-null int64
# time_in_hospital            101766 non-null int64
# payer_code                  101766 non-null object
# medical_specialty           101766 non-null object
# num_lab_procedures          101766 non-null int64
# num_procedures              101766 non-null int64
# num_medications             101766 non-null int64
# number_outpatient           101766 non-null int64
# ...

# %%
df.isna().any().any() #to find any nan values
# Out:
# False

# %%
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
for column in df:
#     print(column)
#     print(counter)
    counter = 0
    for element in df[column]:
        #print(row)
        if element == '?':
            counter += 1
    print('{} : {}'.format(column, counter))
# Out:
# encounter_id : 0
# patient_nbr : 0
# race : 2273
# gender : 0
# age : 0
# weight : 98569
# admission_type_id : 0
# discharge_disposition_id : 0
# admission_source_id : 0
# time_in_hospital : 0
# payer_code : 40256
# medical_specialty : 49949
# num_lab_procedures : 0
# num_procedures : 0
# num_medications : 0
# number_outpatient : 0
# number_emergency : 0
# number_inpatient : 0
# diag_1 : 21
# diag_2 : 358
# diag_3 : 1423
# number_diagnoses : 0
# max_glu_serum : 0
# A1Cresult : 0
# metformin : 0
# repaglinide : 0
# nateglinide : 0
# chlorpropamide : 0
# glimepiride : 0
# acetohexamide : 0
# glipizide : 0
# glyburide : 0
# tolbutamide : 0
# pioglitazone : 0
# rosiglitazone : 0
# acarbose : 0
# miglitol : 0
# troglitazone : 0
# tolazamide : 0
# examide : 0
# citoglipton : 0
# insulin : 0
# glyburide-metformin : 0
# glipizide-metformin : 0
# glimepiride-pioglitazone : 0
# metformin-rosiglitazone : 0
# metformin-pioglitazone : 0
# change : 0
# diabetesMed : 0
# readmitted : 0

# %%
for column in df:
#     print(column)
#     print(counter)
    counter = 0
    for element in df[column]:
        #print(row)
        if element == 'No':
            counter += 1
    print('{} : {}'.format(column, counter))
# Out:
# encounter_id : 0
# patient_nbr : 0
# race : 0
# gender : 0
# age : 0
# weight : 0
# admission_type_id : 0
# discharge_disposition_id : 0
# admission_source_id : 0
# time_in_hospital : 0
# payer_code : 0
# medical_specialty : 0
# num_lab_procedures : 0
# num_procedures : 0
# num_medications : 0
# number_outpatient : 0
# number_emergency : 0
# number_inpatient : 0
# diag_1 : 0
# diag_2 : 0
# diag_3 : 0
# number_diagnoses : 0
# max_glu_serum : 0
# A1Cresult : 0
# metformin : 81778
# repaglinide : 100227
# nateglinide : 101063
# chlorpropamide : 101680
# glimepiride : 96575
# acetohexamide : 101765
# glipizide : 89080
# glyburide : 91116
# tolbutamide : 101743
# pioglitazone : 94438
# rosiglitazone : 95401
# acarbose : 101458
# miglitol : 101728
# troglitazone : 101763
# tolazamide : 101727
# examide : 101766
# citoglipton : 101766
# insulin : 47383
# glyburide-metformin : 101060
# glipizide-metformin : 101753
# glimepiride-pioglitazone : 101765
# metformin-rosiglitazone : 101764
# ...

# %%
df.drop(['weight', 'payer_code', 'patient_nbr', 'medical_specialty', 'examide', 'citoglipton', 'glimepiride-pioglitazone', 'metformin-rosiglitazone', 
         'metformin-pioglitazone', 'acetohexamide', 'troglitazone' ], axis = 1, inplace = True)
df.head(10)
# Out:
#    encounter_id             race  gender       age  admission_type_id  \
# 0       2278392        Caucasian  Female    [0-10)                  6
# 1        149190        Caucasian  Female   [10-20)                  1
# 2         64410  AfricanAmerican  Female   [20-30)                  1
# 3        500364        Caucasian    Male   [30-40)                  1
# 4         16680        Caucasian    Male   [40-50)                  1
# 5         35754        Caucasian    Male   [50-60)                  2
# 6         55842        Caucasian    Male   [60-70)                  3
# 7         63768        Caucasian    Male   [70-80)                  1
# 8         12522        Caucasian  Female   [80-90)                  2
# 9         15738        Caucasian  Female  [90-100)                  3
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                        25                    1                 1
# ...

# %%
df['readmitted'] = df['readmitted'].map(lambda x: 2 if x=='>30' else (1 if x=='<30' else 0))
df.readmitted = df.readmitted.astype('int64')
df.head()
# Out:
#    encounter_id             race  gender      age  admission_type_id  \
# 0       2278392        Caucasian  Female   [0-10)                  6
# 1        149190        Caucasian  Female  [10-20)                  1
# 2         64410  AfricanAmerican  Female  [20-30)                  1
# 3        500364        Caucasian    Male  [30-40)                  1
# 4         16680        Caucasian    Male  [40-50)                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                        25                    1                 1
# 1                         1                    7                 3
# 2                         1                    7                 2
# 3                         1                    7                 2
# 4                         1                    7                 1
#
#    num_lab_procedures  num_procedures    ...      rosiglitazone  acarbose  \
# ...

# %%
indexes_to_drop = []
for col in df:
    for index, row in enumerate(df[col]):
        #print(index, row)
        if row == '?':
            indexes_to_drop.append(index)
print(len(indexes_to_drop))
df.drop(index= indexes_to_drop, inplace = True)
df.shape
# Out:
# 4075
# (98053, 39)

# %%
#to_drop = df[df['race'] == '?']
#df.drop(to_drop.index, axis=0, inplace=True)

#to_drop = df[df['diag_1'] == '?']
#df.drop(to_drop.index, axis=0, inplace=True)
#df.diag_1 = df.diag_1.astype('float')

#to_drop = df[df['diag_2'] == '?']
#df.drop(to_drop.index, axis=0, inplace=True)
#df.diag_2 = df.diag_2.astype('float')

#to_drop = df[df['diag_3'] == '?']
#df.drop(to_drop.index, axis=0, inplace=True)
#df.diag_3 = df.diag_3.astype('float')

# %%
df['diag_1'].str.startswith('V').sum()
for col
# Out:
# 1600

# %%
df.info()

# %%
race_list = df.index[df['gender'] == '?'].tolist()
print(len(race_list))

# %%
for each in df["encounter_id"][0:5]:
    print(type(each))

# %%
df.drop

# %%
df['race'].value_counts()

# %%
df['num_procedures'].unique()

# %%
df.groupby(['race', 'readmitted'])['readmitted'].count()

# %%
df.groupby(['age','readmitted']).count()

# %%
df['age'].unique()
